# %%
target_per_day = subset_df.groupby(['day', 'IncidentGrade']).size().unstack(fill_value=0)

# Plot time series for each class
plt.figure(figsize=(10,6))
target_per_day.plot(ax=plt.gca())
plt.title('Frequency of Target Classes Over Time')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
target_per_day = subset_df.groupby(['month', 'IncidentGrade']).size().unstack(fill_value=0)

# Plot time series for each class
plt.figure(figsize=(10,6))
target_per_day.plot(ax=plt.gca())
plt.title('Frequency of Target Classes Over Time')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
target_per_day = subset_df.groupby(['year', 'IncidentGrade']).size().unstack(fill_value=0)

# Plot time series for each class
plt.figure(figsize=(10,6))
target_per_day.plot(ax=plt.gca())
plt.title('Frequency of Target Classes Over Time')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
target_per_day = subset_df.groupby(['Hour', 'IncidentGrade']).size().unstack(fill_value=0)

# Plot time series for each class
plt.figure(figsize=(10,6))
target_per_day.plot(ax=plt.gca())
plt.title('Frequency of Target Classes Over Time')
plt.xlabel('Hour')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
target_per_day = subset_df.groupby(['minutes', 'IncidentGrade']).size().unstack(fill_value=0)

# Plot time series for each class
plt.figure(figsize=(10,6))
target_per_day.plot(ax=plt.gca())
plt.title('Frequency of Target Classes Over Time')
plt.xlabel('Minutes')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Distribution of the target variable
subset_df['IncidentGrade'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IncidentGrade'>

# %%
subset_df.EvidenceRole.value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='EvidenceRole'>
